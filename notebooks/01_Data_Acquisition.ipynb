# %%
import pandas as pd

url = (
    "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?"
    "query=select+pl_name,hostname,pl_rade,pl_bmasse,pl_orbsmax,pl_orbeccen,"
    "pl_eqt,pl_insol,st_teff,st_rad,st_mass,st_age,st_spectype,disc_year"
    "+from+pscomppars&format=csv"
)

df = pd.read_csv(url)
print(df.shape)
df.to_csv("C:/Projects/EHS/data/raw_exoplanets.csv", index=False)
# Out:
# (6298, 14)

# %%
import pandas as pd
df = pd.read_csv("C:/Projects/EHS/data/raw_exoplanets.csv")
print("Shape:", df.shape)
print("Columns:", list(df.columns))
expected_cols = ['pl_name','hostname','pl_rade','pl_bmasse','pl_orbsmax',
                  'pl_orbeccen','pl_eqt','pl_insol','st_teff','st_rad',
                  'st_mass','st_age','st_spectype','disc_year']
missing_cols = [c for c in expected_cols if c not in df.columns]
print("Missing columns:", missing_cols if missing_cols else "None — good")

print("Row count:", len(df))
print(df.isna().sum())
known = ['Earth', 'Kepler-22 b', '51 Eri b', 'TRAPPIST-1 e']
for name in known:
    match = df[df['pl_name'].str.contains(name, case=False, na=False)]
    print(f"{name}: {'found' if not match.empty else 'NOT FOUND'}")
print(df[['pl_rade','pl_bmasse','pl_eqt','pl_insol','pl_orbeccen']].describe())
# Out:
# Shape: (6298, 14)
# Columns: ['pl_name', 'hostname', 'pl_rade', 'pl_bmasse', 'pl_orbsmax', 'pl_orbeccen', 'pl_eqt', 'pl_insol', 'st_teff', 'st_rad', 'st_mass', 'st_age', 'st_spectype', 'disc_year']
# Missing columns: None — good
# Row count: 6298
# pl_name           0
# hostname          0
# pl_rade          50
# pl_bmasse        31
# pl_orbsmax      425
# pl_orbeccen    1051
# pl_eqt          521
# pl_insol        576
# st_teff         294
# st_rad          318
# st_mass           9
# st_age         1430
# st_spectype    3969
# disc_year         1
# dtype: int64
# Earth: NOT FOUND
# Kepler-22 b: found
# 51 Eri b: found
# TRAPPIST-1 e: found
#            pl_rade    pl_bmasse       pl_eqt       pl_insol  pl_orbeccen
# count  6248.000000  6267.000000  5777.000000    5722.000000  5247.000000
# mean      5.814146   400.346546   834.310038     532.279797     0.079414
# std       5.407920  1131.363115   495.248755    9972.953022     0.152996
# min       0.309800     0.020000     1.480000       0.000000     0.000000
# 25%       1.840000     4.285000   486.000000      10.143425     0.000000
# 50%       2.846633     9.200000   755.550000      65.603500     0.000000
# 75%      11.900000   185.294423  1092.000000     279.063750     0.091000
# max      87.205870  9534.852210  7777.780000  636352.125800     0.950000
